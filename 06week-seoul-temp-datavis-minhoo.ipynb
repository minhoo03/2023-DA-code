# %%
import matplotlib as mpl 
mpl.__version__ 
import numpy as np 
np.__version__
# Out:
# '1.21.5'

# %%
# import csv

# f = open('seoul.csv', encoding='cp949')
# data = csv.reader(f)

# header = next(data)

# for row in data:
#     print(row[4])

# f.close()

# %%
import csv

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

result = [] # 최고 기온 데이터를 저장할 리스트

for row in data:
    if row[4] != '': # 최고 기온 데이터 존재하면
        result.append(float(row[4])) # 최고값을 실수형으로 추가

f.close()
print(len(result))
# Out:
# 41163

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

result = [] # 최고 기온 데이터를 저장할 리스트

for row in data:
    if row[4] != '': # 최고 기온 데이터 존재하면
        result.append(float(row[4])) # 최고값을 실수형으로 추가

f.close()
# print(len(result))

plt.plot(result, 'r')
plt.xlabel('Day')
plt.ylabel('The highest temperature')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

result = [] # 최고 기온 데이터를 저장할 리스트

for row in data:
    if row[4] != '': # 최고 기온 데이터 존재하면
        result.append(float(row[4])) # 최고값을 실수형으로 추가

f.close()
# print(len(result))

plt.figure(figsize=(10, 2))
plt.plot(result, 'r')
plt.xlabel('Day')
plt.ylabel('The highest temperature')
plt.show()

# %%
s = 'Happy New Year!'
print(s.split())
# Out:
# ['Happy', 'New', 'Year!']

# %%
date = '2020-12-25'
print(date.split('-'))

print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
# Out:
# ['2020', '12', '25']
# 2020
# 12
# 25

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

result = [] # 최고 기온 데이터를 저장할 리스트

for row in data:
    if row[4] != '': # 최고 기온 데이터 존재하면
        if row[0].split('-')[1] == '12': # 12월에 해당하는 값이라면
            result.append(float(row[4])) # 최고값을 실수형으로 추가

f.close()
# print(len(result))

plt.figure(figsize=(10, 2))
plt.plot(result, 'r')
plt.xlabel('Day (December)')
plt.ylabel('The highest temperature')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

result = [] # 최고 기온 데이터를 저장할 리스트

for row in data:
    if row[4] != '': # 최고 기온 데이터 존재하면
        if row[0].split('-')[1] == '12' and row[0].split('-')[2] == '25': # 12월 25일에 해당하는 값이라면
            result.append(float(row[4])) # 최고값을 실수형으로 추가

f.close()
# print(len(result))

plt.figure(figsize=(10, 2))
plt.plot(result, 'r')
plt.xlabel('Day (December)')
plt.ylabel('The highest temperature')
plt.show()

# %%
# 13페이지
plt.rc('font', family='Malgun Gothic')
plt.title('크리스마스의 기온 변화 그래프')

plt.rcParams['axes.unicode_minus'] = False

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

temp_day = []
temp_mean = []
year = []

for row in data:
    if int(row[0].split('-')[0]) > 1907:
        if row[2] != '':
            temp_day.append(float(row[2]))
            if (row[0].split('-')[1] == '12') and (row[0].split('-')[2] == '31'):
                year.append(int(row[0].split('-')[0]))

                temp_mean.append(sum(temp_day) / len(temp_day))
                temp_day=[]
f.close()

plt.figure(figsize=(10, 4))
# 13페이지
plt.rc('font', family='Malgun Gothic')
plt.title('평균 기온 변화 그래프')
plt.plot(year, temp_mean, color='k', marker='d')
plt.xlabel('Year')
plt.ylabel('Avg Temp')
plt.grid()
plt.show()

# %%
# 18페이지

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
result = []

for row in data:
    if row[4] != '':
        result.append(float(row[4]))

plt.hist(result, bins=100, color='r')
plt.show()

# %%
# 18페이지

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
aug = []

for row in data:
    month = row[0].split('-')[1]
    if row[4] != '':
        if month == '08':
            aug.append(float(row[4])) # 8월 최고 기온 데이터를 히스토그램으로 시각화

plt.hist(aug, bins=100, color='r')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
jan = []
aug = []

for row in data:
    month = row[0].split('-')[1]
    if row[4] != '':
        if month == '01':
            jan.append(float(row[4]))
        elif month == '08':
            aug.append(float(row[4])) # 8월 최고 기온 데이터를 히스토그램으로 시각화

plt.hist(jan, bins=100, color='b', label='jan.')
plt.hist(aug, bins=100, color='r', label='Aug.')
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
result = []

for row in data:
    if row[4] != '':
        result.append(float(row[4]))

plt.boxplot(result)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
jan = []
aug = []

for row in data:
    month = row[0].split('-')[1]
    if row[4] != '':
        if month == '01':
            jan.append(float(row[4]))
        elif month == '08':
            aug.append(float(row[4]))

plt.boxplot(jan)
plt.boxplot(aug)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
jan = []
aug = []

for row in data:
    month = row[0].split('-')[1]
    if row[4] != '':
        if month == '01':
            jan.append(float(row[4]))
        elif month == '08':
            aug.append(float(row[4]))

plt.boxplot(jan, aug)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
month = [[], [], [], [], [], [], [], [], [], [], [], []]

for row in data:
    if row[4] != '':
        month[int(row[0].split('-')[1])-1].append(float(row[4]))

plt.boxplot(month)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

day = []

for i in range(31):
    day.append([])

for row in data:
    if row[4] != '':
        if row[0].split('-')[1] == '01':
            day[int(row[0].split('-')[2])-1].append(float(row[4]))

plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.boxplot(day, showfliers=False)
plt.show()
